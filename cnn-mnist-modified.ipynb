# %% [markdown]
# ## Handwritten Digit Classifier using a Simple Neural Network with 99.4% accuracy
#
# ### MNIST Dataset
# The MNIST database (Modified National Institute of Standards and Technology database) is a large database of handwritten digits that is commonly used for training various image processing systems. This dataset is considered to be the "hello world" dataset for Computer Vision.
#
# I have written a blog to give a better explanation of the approach I have used, here is the link - https://medium.com/analytics-vidhya/get-started-with-your-first-deep-learning-project-7d989cb13ae5
#
# It has a training set of 60,000 examples and a test set of 10,000 examples for handwritten digits with a fixed dimension of 28X28 pixels. The goal is to correctly identify digits and find ways to improve the performance of the model. So let's dive into it -

# %% [markdown]
# ## Import the required libraries

# %%
import numpy as np         
import pandas as pd
import matplotlib.pyplot as plt      
import random                        

from keras.datasets import mnist     
from keras.models import Sequential  

from keras.layers.core import Dense, Dropout, Activation 
from keras.utils import np_utils                         
from sklearn.model_selection import train_test_split

# %% [markdown]
# NumPy is an advanced Math Library in Python. Matplotlib will be used to plot graphs and for data visualization. We will import the MNIST dataset which is pre-loaded in Keras. We will use the Sequential Model and import the basic layers and util tools.

# %% [markdown]
# ## Load the Dataset

# %%
train_inputs = pd.read_csv("../input/mnistmodified/train.csv")
train_inputs = np.array(train_inputs)[:,:-1] 

train_labels = pd.read_csv("../input/mnistmodified/train_result.csv")
train_labels = np.array(train_labels)[:,1] 

test_inputs = pd.read_csv("../input/mnistmodified/test.csv")
test_inputs = np.array(test_inputs)[:,:-1] 

#X_train, X_test, y_train, y_test = train_test_split(train_inputs, train_labels, test_size=0.30)
X_train = train_inputs
y_train = train_labels
X_test = test_inputs
y_test = train_labels[40000:] #Pas de y_test mais en attendant

# %%
test_data = pd.read_csv('../input/mnistmodified/test.csv', delimiter = ',', header = 0, usecols = [x for x in range(0, 1568)])

# %% [markdown]
# We load the dataset and verify the dimensions of the training and testing sets.

# %%
for i in range(16):
    plt.subplot(4,4,i+1)
    num = random.randint(0, len(X_train))
    plt.imshow(X_train[num].reshape(28,56), cmap='gray', interpolation='none')
    plt.title("Class {}".format(y_train[num]))
    
plt.tight_layout()

# %% [markdown]
# Here we are randomly selecting 9 images from the dataset and plotting them to get an idea of the handwritten digits and their respective classes.

# %% [markdown]
# ## Data Preprocessing
#
# Instead of a 28 x 28 matrix, we build our network to accept a 784-length vector. Pixel values range from 0 to 255 where 0 is black and 255 is pure white. We will normalize these values by dividing them by 255 so that we get the output pixel values between [0,1] in the same magnitude.
#
# Note that we are working with grayscale images of dimension 28 x 28 pixels. If we have color images, we have 3 channels for RGB, i.e. 28 x 28 x 3, each with pixel value in the range 0 to 255.

# %%
print("Training matrix shape", X_train.shape)
print("Testing matrix shape", X_test.shape)
# Out:
# Training matrix shape (50000, 1568)
# Testing matrix shape (10000, 1568)

# %%
no_classes = 19

Y_train = np_utils.to_categorical(y_train, no_classes)
Y_test = np_utils.to_categorical(y_test, no_classes)

# %% [markdown]
# Since the output will be classified as one of the 10 classes we use one-hot encoding technique to form the output (Y variable). Read more about one-hot encoding here - https://machinelearningmastery.com/why-one-hot-encode-data-in-machine-learning/

# %% [markdown]
# ## Building a 3-layer Neural Network
#
# ![alt text](https://chsasank.github.io/assets/images/crash_course/mnist_net.png)

# %%
model = Sequential()
# Out:
# 2022-10-29 05:30:55.404884: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.

# %% [markdown]
# The sequential API allows you to create models layer-by-layer.

# %% [markdown]
# ## First Hidden Layer

# %%
model.add(Dense(512, input_shape=(1568,)))

# %% [markdown]
# The first hidden layer has 512 nodes (neurons) whose input is a vector of size 784. Each node will receive an element from each input vector and apply some weight and bias to it.

# %%
model.add(Activation('relu'))

# %% [markdown]
# In artificial neural networks, the activation function of a node defines the output of that node given an input or set of inputs. ReLU stands for rectified linear unit, and is a type of activation function. $$ ReLU: f(x) = max (0,x)$$

# %%
model.add(Dropout(0.2))

# %% [markdown]
# Dropout randomly selects a few nodes and nullifies their output (deactivates the node). This helps in ensuring that the model is not overfitted to the training dataset.

# %% [markdown]
# ## Second Hidden Layer

# %%
model.add(Dense(512))
model.add(Activation('relu'))
model.add(Dropout(0.2))

# %% [markdown]
# The second hidden layer also has 512 nodes and it takes input from the 512 nodes in the previous layer and gives its output to the next subsequent layer.

# %% [markdown]
# ## Final Output Layer

# %% [markdown]
# The final layer of 10 neurons in fully-connected to the previous 512-node layer.
# The final layer should be equal to the number of desired output classes.

# %%
model.add(Dense(19))
model.add(Activation('softmax'))

# %% [markdown]
# The Softmax Activation represents a probability distribution over n different possible outcomes. Its values are all non-negative and sum to 1. For example, if the final output is: [0, 0.94, 0, 0, 0, 0, 0, 0.06, 0, 0] then it is most probable that the image is that of the digit 1

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 512)               803328
# _________________________________________________________________
# activation (Activation)      (None, 512)               0
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               262656
# _________________________________________________________________
# activation_1 (Activation)    (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 19)                9747
# _________________________________________________________________
# activation_2 (Activation)    (None, 19)                0
# =================================================================
# Total params: 1,075,731
# Trainable params: 1,075,731
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Compiling the model
#
# When compiling a model, Keras asks you to specify your loss function and your optimizer.

# %%
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %% [markdown]
# The loss function we'll use here is called categorical cross-entropy and is a loss function well-suited to comparing two probability distributions. The cross-entropy is a measure of how different your predicted distribution is from the target distribution. <br><br>
# Optimizers are algorithms or methods used to change the attributes of the neural network such as weights and learning rate to reduce the losses. Optimizers are used to solve optimization problems by minimizing the loss function. In our case, we use the Adam Optimizer.

# %%
history = model.fit(X_train, Y_train,
          batch_size=128, epochs=1000,
          verbose=1)
# Out:
# 2022-10-29 05:31:23.621224: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 1.5837 - accuracy: 0.4806
# Epoch 2/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.7466 - accuracy: 0.7701
# Epoch 3/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.5258 - accuracy: 0.8382
# Epoch 4/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.4144 - accuracy: 0.8724
# Epoch 5/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.3245 - accuracy: 0.9005
# Epoch 6/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.2631 - accuracy: 0.9187
# Epoch 7/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.2238 - accuracy: 0.9298
# Epoch 8/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.1855 - accuracy: 0.9409
# Epoch 9/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.1645 - accuracy: 0.9477
# Epoch 10/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.1473 - accuracy: 0.9528
# Epoch 11/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.1276 - accuracy: 0.9587
# Epoch 12/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.1158 - accuracy: 0.9625
# Epoch 13/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.1077 - accuracy: 0.9652
# Epoch 14/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.1085 - accuracy: 0.9649
# Epoch 15/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0908 - accuracy: 0.9697
# Epoch 16/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0960 - accuracy: 0.9689
# Epoch 17/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0848 - accuracy: 0.9737
# Epoch 18/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0806 - accuracy: 0.9741
# Epoch 19/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0790 - accuracy: 0.9742
# Epoch 20/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0728 - accuracy: 0.9766
# Epoch 21/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0766 - accuracy: 0.9757
# Epoch 22/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0727 - accuracy: 0.9769
# Epoch 23/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0668 - accuracy: 0.9786
# Epoch 24/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0666 - accuracy: 0.9789
# Epoch 25/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0645 - accuracy: 0.9784
# Epoch 26/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0677 - accuracy: 0.9786
# Epoch 27/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0665 - accuracy: 0.9793
# Epoch 28/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0598 - accuracy: 0.9810
# Epoch 29/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0599 - accuracy: 0.9813
# Epoch 30/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0552 - accuracy: 0.9829
# Epoch 31/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0596 - accuracy: 0.9809
# Epoch 32/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0574 - accuracy: 0.9817
# Epoch 33/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0554 - accuracy: 0.9825
# Epoch 34/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0577 - accuracy: 0.9817
# Epoch 35/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0521 - accuracy: 0.9839
# Epoch 36/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0512 - accuracy: 0.9836
# Epoch 37/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0522 - accuracy: 0.9838
# Epoch 38/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0565 - accuracy: 0.9831
# Epoch 39/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0515 - accuracy: 0.9841
# Epoch 40/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0514 - accuracy: 0.9849
# Epoch 41/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0499 - accuracy: 0.9857
# Epoch 42/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0503 - accuracy: 0.9842
# Epoch 43/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0473 - accuracy: 0.9864
# Epoch 44/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0501 - accuracy: 0.9855
# Epoch 45/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0519 - accuracy: 0.9850
# Epoch 46/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0415 - accuracy: 0.9874
# Epoch 47/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0419 - accuracy: 0.9868
# Epoch 48/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0511 - accuracy: 0.9847
# Epoch 49/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0506 - accuracy: 0.9849
# Epoch 50/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0493 - accuracy: 0.9848
# Epoch 51/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0441 - accuracy: 0.9871
# Epoch 52/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0446 - accuracy: 0.9868
# Epoch 53/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0395 - accuracy: 0.9879
# Epoch 54/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0477 - accuracy: 0.9864
# Epoch 55/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0396 - accuracy: 0.9879
# Epoch 56/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0424 - accuracy: 0.9872
# Epoch 57/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0478 - accuracy: 0.9863
# Epoch 58/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0403 - accuracy: 0.9877
# Epoch 59/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0421 - accuracy: 0.9872
# Epoch 60/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0448 - accuracy: 0.9871
# Epoch 61/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0366 - accuracy: 0.9891
# Epoch 62/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0415 - accuracy: 0.9879
# Epoch 63/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0373 - accuracy: 0.9892
# Epoch 64/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0408 - accuracy: 0.9883
# Epoch 65/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0440 - accuracy: 0.9867
# Epoch 66/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0410 - accuracy: 0.9880
# Epoch 67/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0432 - accuracy: 0.9877
# Epoch 68/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0459 - accuracy: 0.9870
# Epoch 69/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0398 - accuracy: 0.9892
# Epoch 70/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0404 - accuracy: 0.9885
# Epoch 71/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0398 - accuracy: 0.9894
# Epoch 72/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0359 - accuracy: 0.9901
# Epoch 73/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0348 - accuracy: 0.9902
# Epoch 74/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0418 - accuracy: 0.9887
# Epoch 75/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0362 - accuracy: 0.9902
# Epoch 76/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0335 - accuracy: 0.9903
# Epoch 77/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0374 - accuracy: 0.9894
# Epoch 78/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0474 - accuracy: 0.9871
# Epoch 79/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0367 - accuracy: 0.9898
# Epoch 80/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0400 - accuracy: 0.9885
# Epoch 81/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0383 - accuracy: 0.9902
# Epoch 82/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0346 - accuracy: 0.9900
# Epoch 83/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0365 - accuracy: 0.9897
# Epoch 84/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0383 - accuracy: 0.9890
# Epoch 85/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0376 - accuracy: 0.9895
# Epoch 86/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0308 - accuracy: 0.9914
# Epoch 87/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0284 - accuracy: 0.9919
# Epoch 88/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0375 - accuracy: 0.9899
# Epoch 89/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0393 - accuracy: 0.9897
# Epoch 90/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0342 - accuracy: 0.9905
# Epoch 91/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0410 - accuracy: 0.9891
# Epoch 92/1000
# 391/391 [==============================] - 6s 15ms/step - loss: 0.0336 - accuracy: 0.9905
# Epoch 93/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0356 - accuracy: 0.9901
# Epoch 94/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0340 - accuracy: 0.9909
# Epoch 95/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0364 - accuracy: 0.9904
# Epoch 96/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0301 - accuracy: 0.9923
# Epoch 97/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0324 - accuracy: 0.9908
# Epoch 98/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0348 - accuracy: 0.9910
# Epoch 99/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0375 - accuracy: 0.9898
# Epoch 100/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0346 - accuracy: 0.9908
# Epoch 101/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0371 - accuracy: 0.9901
# Epoch 102/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0280 - accuracy: 0.9922
# Epoch 103/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0323 - accuracy: 0.9914
# Epoch 104/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0325 - accuracy: 0.9907
# Epoch 105/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0352 - accuracy: 0.9909
# Epoch 106/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0338 - accuracy: 0.9910
# Epoch 107/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0374 - accuracy: 0.9900
# Epoch 108/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0361 - accuracy: 0.9902
# Epoch 109/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0323 - accuracy: 0.9913
# Epoch 110/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0301 - accuracy: 0.9917
# Epoch 111/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0319 - accuracy: 0.9917
# Epoch 112/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0317 - accuracy: 0.9918
# Epoch 113/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0357 - accuracy: 0.9911
# Epoch 114/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0346 - accuracy: 0.9916
# Epoch 115/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0319 - accuracy: 0.9917
# Epoch 116/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0316 - accuracy: 0.9913
# Epoch 117/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0326 - accuracy: 0.9915
# Epoch 118/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0354 - accuracy: 0.9910
# Epoch 119/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0356 - accuracy: 0.9907
# Epoch 120/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0356 - accuracy: 0.9909
# Epoch 121/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0348 - accuracy: 0.9916
# Epoch 122/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0314 - accuracy: 0.9922
# Epoch 123/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0303 - accuracy: 0.9926
# Epoch 124/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0380 - accuracy: 0.9904
# Epoch 125/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0292 - accuracy: 0.9922
# Epoch 126/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0312 - accuracy: 0.9918
# Epoch 127/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0325 - accuracy: 0.9918
# Epoch 128/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0313 - accuracy: 0.9922
# Epoch 129/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0300 - accuracy: 0.9925
# Epoch 130/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0337 - accuracy: 0.9913
# Epoch 131/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0294 - accuracy: 0.9921
# Epoch 132/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0288 - accuracy: 0.9923
# Epoch 133/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0304 - accuracy: 0.9922
# Epoch 134/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0295 - accuracy: 0.9919
# Epoch 135/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0317 - accuracy: 0.9921
# Epoch 136/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0359 - accuracy: 0.9914
# Epoch 137/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0344 - accuracy: 0.9914
# Epoch 138/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0316 - accuracy: 0.9922
# Epoch 139/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0287 - accuracy: 0.9928
# Epoch 140/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0311 - accuracy: 0.9923
# Epoch 141/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0301 - accuracy: 0.9923
# Epoch 142/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0371 - accuracy: 0.9916
# Epoch 143/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0273 - accuracy: 0.9933
# Epoch 144/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0306 - accuracy: 0.9923
# Epoch 145/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0316 - accuracy: 0.9924
# Epoch 146/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0318 - accuracy: 0.9919
# Epoch 147/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0300 - accuracy: 0.9926
# Epoch 148/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0348 - accuracy: 0.9919
# Epoch 149/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0283 - accuracy: 0.9932
# Epoch 150/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0279 - accuracy: 0.9935
# Epoch 151/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0352 - accuracy: 0.9915
# Epoch 152/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0326 - accuracy: 0.9922
# Epoch 153/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0256 - accuracy: 0.9931
# Epoch 154/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0289 - accuracy: 0.9929
# Epoch 155/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0334 - accuracy: 0.9924
# Epoch 156/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0299 - accuracy: 0.9925
# Epoch 157/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0313 - accuracy: 0.9925
# Epoch 158/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0322 - accuracy: 0.9925
# Epoch 159/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0326 - accuracy: 0.9930
# Epoch 160/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0292 - accuracy: 0.9930
# Epoch 161/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0317 - accuracy: 0.9926
# Epoch 162/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0359 - accuracy: 0.9922
# Epoch 163/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0289 - accuracy: 0.9928
# Epoch 164/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0268 - accuracy: 0.9937
# Epoch 165/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0265 - accuracy: 0.9934
# Epoch 166/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0330 - accuracy: 0.9927
# Epoch 167/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0291 - accuracy: 0.9929
# Epoch 168/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0302 - accuracy: 0.9932
# Epoch 169/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0319 - accuracy: 0.9926
# Epoch 170/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0300 - accuracy: 0.9929
# Epoch 171/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0259 - accuracy: 0.9936
# Epoch 172/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0295 - accuracy: 0.9925
# Epoch 173/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0291 - accuracy: 0.9932
# Epoch 174/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0295 - accuracy: 0.9931
# Epoch 175/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0242 - accuracy: 0.9941
# Epoch 176/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0284 - accuracy: 0.9936
# Epoch 177/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0276 - accuracy: 0.9930
# Epoch 178/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0304 - accuracy: 0.9930
# Epoch 179/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0365 - accuracy: 0.9919
# Epoch 180/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0288 - accuracy: 0.9930
# Epoch 181/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0323 - accuracy: 0.9921
# Epoch 182/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0308 - accuracy: 0.9927
# Epoch 183/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0314 - accuracy: 0.9928
# Epoch 184/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0365 - accuracy: 0.9920
# Epoch 185/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0249 - accuracy: 0.9939
# Epoch 186/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0319 - accuracy: 0.9929
# Epoch 187/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0310 - accuracy: 0.9928
# Epoch 188/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0310 - accuracy: 0.9930
# Epoch 189/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0295 - accuracy: 0.9933
# Epoch 190/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0346 - accuracy: 0.9923
# Epoch 191/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0311 - accuracy: 0.9931
# Epoch 192/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0291 - accuracy: 0.9935
# Epoch 193/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0293 - accuracy: 0.9938
# Epoch 194/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0260 - accuracy: 0.9937
# Epoch 195/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0321 - accuracy: 0.9930
# Epoch 196/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0262 - accuracy: 0.9935
# Epoch 197/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0315 - accuracy: 0.9930
# Epoch 198/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0280 - accuracy: 0.9933
# Epoch 199/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0255 - accuracy: 0.9939
# Epoch 200/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0269 - accuracy: 0.9937
# Epoch 201/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0271 - accuracy: 0.9939
# Epoch 202/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0281 - accuracy: 0.9937
# Epoch 203/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0316 - accuracy: 0.9932
# Epoch 204/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0296 - accuracy: 0.9932
# Epoch 205/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0249 - accuracy: 0.9938
# Epoch 206/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0253 - accuracy: 0.9942
# Epoch 207/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0285 - accuracy: 0.9936
# Epoch 208/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0335 - accuracy: 0.9925
# Epoch 209/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0291 - accuracy: 0.9933
# Epoch 210/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0234 - accuracy: 0.9944
# Epoch 211/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0320 - accuracy: 0.9926
# Epoch 212/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0314 - accuracy: 0.9935
# Epoch 213/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0283 - accuracy: 0.9938
# Epoch 214/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0298 - accuracy: 0.9932
# Epoch 215/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0248 - accuracy: 0.9939
# Epoch 216/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0206 - accuracy: 0.9949
# Epoch 217/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0267 - accuracy: 0.9937
# Epoch 218/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0279 - accuracy: 0.9941
# Epoch 219/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0307 - accuracy: 0.9934
# Epoch 220/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0257 - accuracy: 0.9940
# Epoch 221/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0301 - accuracy: 0.9931
# Epoch 222/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0294 - accuracy: 0.9936
# Epoch 223/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0292 - accuracy: 0.9938
# Epoch 224/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0287 - accuracy: 0.9940
# Epoch 225/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0281 - accuracy: 0.9938
# Epoch 226/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0241 - accuracy: 0.9946
# Epoch 227/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0321 - accuracy: 0.9928
# Epoch 228/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0296 - accuracy: 0.9941
# Epoch 229/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0282 - accuracy: 0.9941
# Epoch 230/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0254 - accuracy: 0.9945
# Epoch 231/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0273 - accuracy: 0.9936
# Epoch 232/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0301 - accuracy: 0.9938
# Epoch 233/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0288 - accuracy: 0.9939
# Epoch 234/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0243 - accuracy: 0.9946
# Epoch 235/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0259 - accuracy: 0.9946
# Epoch 236/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0263 - accuracy: 0.9942
# Epoch 237/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0276 - accuracy: 0.9943
# Epoch 238/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0257 - accuracy: 0.9947
# Epoch 239/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0369 - accuracy: 0.9924
# Epoch 240/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0332 - accuracy: 0.9930
# Epoch 241/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0266 - accuracy: 0.9937
# Epoch 242/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0279 - accuracy: 0.9944
# Epoch 243/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0306 - accuracy: 0.9934
# Epoch 244/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0270 - accuracy: 0.9945
# Epoch 245/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0306 - accuracy: 0.9937
# Epoch 246/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0303 - accuracy: 0.9941
# Epoch 247/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0289 - accuracy: 0.9941
# Epoch 248/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0234 - accuracy: 0.9950
# Epoch 249/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0318 - accuracy: 0.9937
# Epoch 250/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0301 - accuracy: 0.9938
# Epoch 251/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0260 - accuracy: 0.9947
# Epoch 252/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0262 - accuracy: 0.9945
# Epoch 253/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0265 - accuracy: 0.9941
# Epoch 254/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0269 - accuracy: 0.9947
# Epoch 255/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0299 - accuracy: 0.9941
# Epoch 256/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0260 - accuracy: 0.9938
# Epoch 257/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0312 - accuracy: 0.9935
# Epoch 258/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0291 - accuracy: 0.9942
# Epoch 259/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0268 - accuracy: 0.9948
# Epoch 260/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0312 - accuracy: 0.9937
# Epoch 261/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0236 - accuracy: 0.9948
# Epoch 262/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0271 - accuracy: 0.9948
# Epoch 263/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0254 - accuracy: 0.9946
# Epoch 264/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0312 - accuracy: 0.9936
# Epoch 265/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0229 - accuracy: 0.9952
# Epoch 266/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0295 - accuracy: 0.9937
# Epoch 267/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0250 - accuracy: 0.9950
# Epoch 268/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0239 - accuracy: 0.9947
# Epoch 269/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0232 - accuracy: 0.9950
# Epoch 270/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0288 - accuracy: 0.9943
# Epoch 271/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0243 - accuracy: 0.9946
# Epoch 272/1000
# 391/391 [==============================] - 4s 12ms/step - loss: 0.0307 - accuracy: 0.9942
# Epoch 273/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0272 - accuracy: 0.9941
# Epoch 274/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0301 - accuracy: 0.9939
# Epoch 275/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0329 - accuracy: 0.9940
# Epoch 276/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0303 - accuracy: 0.9940
# Epoch 277/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0257 - accuracy: 0.9947
# Epoch 278/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0272 - accuracy: 0.9945
# Epoch 279/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0248 - accuracy: 0.9946
# Epoch 280/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0262 - accuracy: 0.9945
# Epoch 281/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0302 - accuracy: 0.9941
# Epoch 282/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0286 - accuracy: 0.9942
# Epoch 283/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0320 - accuracy: 0.9942
# Epoch 284/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0322 - accuracy: 0.9944
# Epoch 285/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0268 - accuracy: 0.9951
# Epoch 286/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0271 - accuracy: 0.9943
# Epoch 287/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0239 - accuracy: 0.9951
# Epoch 288/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0264 - accuracy: 0.9947
# Epoch 289/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0274 - accuracy: 0.9948
# Epoch 290/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0224 - accuracy: 0.9955
# Epoch 291/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0247 - accuracy: 0.9949
# Epoch 292/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0320 - accuracy: 0.9936
# Epoch 293/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0272 - accuracy: 0.9945
# Epoch 294/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0325 - accuracy: 0.9938
# Epoch 295/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0240 - accuracy: 0.9948
# Epoch 296/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0254 - accuracy: 0.9950
# Epoch 297/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0251 - accuracy: 0.9954
# Epoch 298/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0330 - accuracy: 0.9937
# Epoch 299/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0285 - accuracy: 0.9942
# Epoch 300/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0303 - accuracy: 0.9941
# Epoch 301/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0310 - accuracy: 0.9943
# Epoch 302/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0261 - accuracy: 0.9946
# Epoch 303/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0260 - accuracy: 0.9948
# Epoch 304/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0247 - accuracy: 0.9947
# Epoch 305/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0255 - accuracy: 0.9951
# Epoch 306/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0288 - accuracy: 0.9942
# Epoch 307/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0288 - accuracy: 0.9947
# Epoch 308/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0270 - accuracy: 0.9946
# Epoch 309/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0211 - accuracy: 0.9955
# Epoch 310/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0275 - accuracy: 0.9944
# Epoch 311/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0267 - accuracy: 0.9950
# Epoch 312/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0277 - accuracy: 0.9944
# Epoch 313/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0273 - accuracy: 0.9944
# Epoch 314/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0287 - accuracy: 0.9941
# Epoch 315/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0260 - accuracy: 0.9947
# Epoch 316/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0263 - accuracy: 0.9947
# Epoch 317/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0260 - accuracy: 0.9944
# Epoch 318/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0249 - accuracy: 0.9953
# Epoch 319/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0266 - accuracy: 0.9949
# Epoch 320/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0294 - accuracy: 0.9948
# Epoch 321/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0261 - accuracy: 0.9948
# Epoch 322/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0257 - accuracy: 0.9948
# Epoch 323/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0281 - accuracy: 0.9948
# Epoch 324/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0256 - accuracy: 0.9948
# Epoch 325/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0284 - accuracy: 0.9946
# Epoch 326/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0311 - accuracy: 0.9938
# Epoch 327/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0290 - accuracy: 0.9950
# Epoch 328/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0291 - accuracy: 0.9946
# Epoch 329/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0270 - accuracy: 0.9954
# Epoch 330/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0264 - accuracy: 0.9947
# Epoch 331/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0280 - accuracy: 0.9949
# Epoch 332/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0292 - accuracy: 0.9947
# Epoch 333/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0283 - accuracy: 0.9952
# Epoch 334/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0273 - accuracy: 0.9953
# Epoch 335/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0235 - accuracy: 0.9951
# Epoch 336/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0236 - accuracy: 0.9953
# Epoch 337/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0228 - accuracy: 0.9959
# Epoch 338/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0263 - accuracy: 0.9953
# Epoch 339/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0288 - accuracy: 0.9944
# Epoch 340/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0280 - accuracy: 0.9950
# Epoch 341/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0246 - accuracy: 0.9951
# Epoch 342/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0324 - accuracy: 0.9941
# Epoch 343/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0290 - accuracy: 0.9949
# Epoch 344/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0259 - accuracy: 0.9947
# Epoch 345/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0229 - accuracy: 0.9954
# Epoch 346/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0310 - accuracy: 0.9946
# Epoch 347/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0287 - accuracy: 0.9949
# Epoch 348/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0294 - accuracy: 0.9948
# Epoch 349/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0265 - accuracy: 0.9953
# Epoch 350/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0271 - accuracy: 0.9947
# Epoch 351/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0271 - accuracy: 0.9951
# Epoch 352/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0204 - accuracy: 0.9959
# Epoch 353/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0253 - accuracy: 0.9953
# Epoch 354/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0236 - accuracy: 0.9954
# Epoch 355/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0292 - accuracy: 0.9952
# Epoch 356/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0300 - accuracy: 0.9947
# Epoch 357/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0292 - accuracy: 0.9950
# Epoch 358/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0283 - accuracy: 0.9951
# Epoch 359/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0298 - accuracy: 0.9950
# Epoch 360/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0250 - accuracy: 0.9953
# Epoch 361/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0287 - accuracy: 0.9950
# Epoch 362/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0240 - accuracy: 0.9951
# Epoch 363/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0264 - accuracy: 0.9954
# Epoch 364/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0232 - accuracy: 0.9957
# Epoch 365/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0291 - accuracy: 0.9951
# Epoch 366/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0271 - accuracy: 0.9956
# Epoch 367/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0213 - accuracy: 0.9960
# Epoch 368/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0267 - accuracy: 0.9947
# Epoch 369/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0305 - accuracy: 0.9948
# Epoch 370/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0309 - accuracy: 0.9946
# Epoch 371/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0283 - accuracy: 0.9949
# Epoch 372/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0273 - accuracy: 0.9953
# Epoch 373/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0274 - accuracy: 0.9955
# Epoch 374/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0294 - accuracy: 0.9947
# Epoch 375/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0303 - accuracy: 0.9950
# Epoch 376/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0284 - accuracy: 0.9951
# Epoch 377/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0263 - accuracy: 0.9954
# Epoch 378/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0236 - accuracy: 0.9959
# Epoch 379/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0306 - accuracy: 0.9952
# Epoch 380/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0298 - accuracy: 0.9952
# Epoch 381/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0272 - accuracy: 0.9953
# Epoch 382/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0277 - accuracy: 0.9949
# Epoch 383/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0263 - accuracy: 0.9949
# Epoch 384/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0358 - accuracy: 0.9943
# Epoch 385/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0301 - accuracy: 0.9948
# Epoch 386/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0298 - accuracy: 0.9948
# Epoch 387/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0266 - accuracy: 0.9952
# Epoch 388/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0215 - accuracy: 0.9961
# Epoch 389/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0282 - accuracy: 0.9952
# Epoch 390/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0290 - accuracy: 0.9951
# Epoch 391/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0267 - accuracy: 0.9955
# Epoch 392/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0324 - accuracy: 0.9950
# Epoch 393/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0225 - accuracy: 0.9957
# Epoch 394/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0248 - accuracy: 0.9957
# Epoch 395/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0268 - accuracy: 0.9953
# Epoch 396/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0264 - accuracy: 0.9952
# Epoch 397/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0248 - accuracy: 0.9957
# Epoch 398/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0246 - accuracy: 0.9956
# Epoch 399/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0376 - accuracy: 0.9945
# Epoch 400/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0285 - accuracy: 0.9953
# Epoch 401/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0246 - accuracy: 0.9956
# Epoch 402/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0274 - accuracy: 0.9954
# Epoch 403/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0331 - accuracy: 0.9944
# Epoch 404/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0277 - accuracy: 0.9952
# Epoch 405/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0240 - accuracy: 0.9955
# Epoch 406/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0245 - accuracy: 0.9958
# Epoch 407/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0289 - accuracy: 0.9950
# Epoch 408/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0287 - accuracy: 0.9944
# Epoch 409/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0297 - accuracy: 0.9953
# Epoch 410/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0280 - accuracy: 0.9949
# Epoch 411/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0244 - accuracy: 0.9955
# Epoch 412/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0237 - accuracy: 0.9960
# Epoch 413/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0231 - accuracy: 0.9959
# Epoch 414/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0294 - accuracy: 0.9950
# Epoch 415/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0297 - accuracy: 0.9952
# Epoch 416/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0268 - accuracy: 0.9954
# Epoch 417/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0219 - accuracy: 0.9961
# Epoch 418/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0251 - accuracy: 0.9954
# Epoch 419/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0237 - accuracy: 0.9960
# Epoch 420/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0291 - accuracy: 0.9954
# Epoch 421/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0339 - accuracy: 0.9944
# Epoch 422/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0283 - accuracy: 0.9957
# Epoch 423/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0303 - accuracy: 0.9951
# Epoch 424/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0266 - accuracy: 0.9955
# Epoch 425/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0287 - accuracy: 0.9950
# Epoch 426/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0242 - accuracy: 0.9957
# Epoch 427/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0249 - accuracy: 0.9955
# Epoch 428/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0215 - accuracy: 0.9961
# Epoch 429/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0301 - accuracy: 0.9947
# Epoch 430/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0299 - accuracy: 0.9950
# Epoch 431/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0251 - accuracy: 0.9960
# Epoch 432/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0237 - accuracy: 0.9964
# Epoch 433/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0252 - accuracy: 0.9955
# Epoch 434/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0243 - accuracy: 0.9957
# Epoch 435/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0296 - accuracy: 0.9952
# Epoch 436/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0247 - accuracy: 0.9960
# Epoch 437/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0288 - accuracy: 0.9948
# Epoch 438/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0262 - accuracy: 0.9957
# Epoch 439/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0292 - accuracy: 0.9955
# Epoch 440/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0277 - accuracy: 0.9957
# Epoch 441/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0283 - accuracy: 0.9953
# Epoch 442/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0260 - accuracy: 0.9952
# Epoch 443/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0280 - accuracy: 0.9956
# Epoch 444/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0323 - accuracy: 0.9950
# Epoch 445/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0295 - accuracy: 0.9951
# Epoch 446/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0250 - accuracy: 0.9955
# Epoch 447/1000
# 391/391 [==============================] - 6s 14ms/step - loss: 0.0253 - accuracy: 0.9957
# Epoch 448/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0228 - accuracy: 0.9962
# Epoch 449/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0305 - accuracy: 0.9953
# Epoch 450/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0246 - accuracy: 0.9958
# Epoch 451/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0276 - accuracy: 0.9955
# Epoch 452/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0264 - accuracy: 0.9957
# Epoch 453/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0284 - accuracy: 0.9953
# Epoch 454/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0314 - accuracy: 0.9950
# Epoch 455/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0243 - accuracy: 0.9963
# Epoch 456/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0225 - accuracy: 0.9959
# Epoch 457/1000
# ...
# Epoch 849/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0345 - accuracy: 0.9969
# Epoch 850/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0182 - accuracy: 0.9975
# Epoch 851/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0267 - accuracy: 0.9971
# Epoch 852/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0231 - accuracy: 0.9972
# Epoch 853/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0291 - accuracy: 0.9968
# Epoch 854/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0361 - accuracy: 0.9964
# Epoch 855/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0281 - accuracy: 0.9971
# Epoch 856/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0252 - accuracy: 0.9973
# Epoch 857/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0266 - accuracy: 0.9968
# Epoch 858/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0225 - accuracy: 0.9974
# Epoch 859/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0254 - accuracy: 0.9972
# Epoch 860/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0348 - accuracy: 0.9967
# Epoch 861/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0318 - accuracy: 0.9964
# Epoch 862/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0293 - accuracy: 0.9966
# Epoch 863/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0323 - accuracy: 0.9972
# Epoch 864/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0420 - accuracy: 0.9967
# Epoch 865/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0223 - accuracy: 0.9974
# Epoch 866/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0316 - accuracy: 0.9970
# Epoch 867/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0262 - accuracy: 0.9969
# Epoch 868/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0213 - accuracy: 0.9976
# Epoch 869/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0285 - accuracy: 0.9970
# Epoch 870/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0341 - accuracy: 0.9968
# Epoch 871/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0328 - accuracy: 0.9963
# Epoch 872/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0286 - accuracy: 0.9965
# Epoch 873/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0329 - accuracy: 0.9967
# Epoch 874/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0221 - accuracy: 0.9973
# Epoch 875/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0240 - accuracy: 0.9975
# Epoch 876/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0357 - accuracy: 0.9963
# Epoch 877/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0334 - accuracy: 0.9962
# Epoch 878/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0387 - accuracy: 0.9964
# Epoch 879/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0295 - accuracy: 0.9967
# Epoch 880/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0315 - accuracy: 0.9970
# Epoch 881/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0293 - accuracy: 0.9968
# Epoch 882/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0317 - accuracy: 0.9967
# Epoch 883/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0294 - accuracy: 0.9965
# Epoch 884/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0346 - accuracy: 0.9969
# Epoch 885/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0258 - accuracy: 0.9972
# Epoch 886/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0270 - accuracy: 0.9971
# Epoch 887/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0325 - accuracy: 0.9965
# Epoch 888/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0246 - accuracy: 0.9969
# Epoch 889/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0291 - accuracy: 0.9969
# Epoch 890/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0286 - accuracy: 0.9970
# Epoch 891/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0305 - accuracy: 0.9967
# Epoch 892/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0310 - accuracy: 0.9968
# Epoch 893/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0337 - accuracy: 0.9966
# Epoch 894/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0295 - accuracy: 0.9968
# Epoch 895/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0219 - accuracy: 0.9976
# Epoch 896/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0270 - accuracy: 0.9968
# Epoch 897/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0244 - accuracy: 0.9973
# Epoch 898/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0197 - accuracy: 0.9980
# Epoch 899/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0284 - accuracy: 0.9970
# Epoch 900/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0276 - accuracy: 0.9971
# Epoch 901/1000
# 391/391 [==============================] - 4s 12ms/step - loss: 0.0332 - accuracy: 0.9968
# Epoch 902/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0307 - accuracy: 0.9968
# Epoch 903/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0260 - accuracy: 0.9967
# Epoch 904/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0340 - accuracy: 0.9966
# Epoch 905/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0217 - accuracy: 0.9971
# Epoch 906/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0376 - accuracy: 0.9968
# Epoch 907/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0368 - accuracy: 0.9965
# Epoch 908/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0318 - accuracy: 0.9967
# Epoch 909/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0314 - accuracy: 0.9967
# Epoch 910/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0326 - accuracy: 0.9968
# Epoch 911/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0355 - accuracy: 0.9961
# Epoch 912/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0301 - accuracy: 0.9967
# Epoch 913/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0337 - accuracy: 0.9964
# Epoch 914/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0322 - accuracy: 0.9966
# Epoch 915/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0339 - accuracy: 0.9965
# Epoch 916/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0308 - accuracy: 0.9971
# Epoch 917/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0261 - accuracy: 0.9968
# Epoch 918/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0285 - accuracy: 0.9971
# Epoch 919/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0288 - accuracy: 0.9969
# Epoch 920/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0279 - accuracy: 0.9971
# Epoch 921/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0287 - accuracy: 0.9969
# Epoch 922/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0297 - accuracy: 0.9970
# Epoch 923/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0267 - accuracy: 0.9972
# Epoch 924/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0271 - accuracy: 0.9965
# Epoch 925/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0339 - accuracy: 0.9969
# Epoch 926/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0387 - accuracy: 0.9963
# Epoch 927/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0327 - accuracy: 0.9964
# Epoch 928/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0338 - accuracy: 0.9967
# Epoch 929/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0351 - accuracy: 0.9969
# Epoch 930/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0241 - accuracy: 0.9972
# Epoch 931/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0328 - accuracy: 0.9966
# Epoch 932/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0285 - accuracy: 0.9970
# Epoch 933/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0247 - accuracy: 0.9976
# Epoch 934/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0324 - accuracy: 0.9966
# Epoch 935/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0383 - accuracy: 0.9966
# Epoch 936/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0272 - accuracy: 0.9968
# Epoch 937/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0278 - accuracy: 0.9971
# Epoch 938/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0269 - accuracy: 0.9967
# Epoch 939/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0222 - accuracy: 0.9971
# Epoch 940/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0258 - accuracy: 0.9969
# Epoch 941/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0283 - accuracy: 0.9973
# Epoch 942/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0260 - accuracy: 0.9972
# Epoch 943/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0264 - accuracy: 0.9972
# Epoch 944/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0278 - accuracy: 0.9971
# Epoch 945/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0302 - accuracy: 0.9968
# Epoch 946/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0248 - accuracy: 0.9972
# Epoch 947/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0231 - accuracy: 0.9971
# Epoch 948/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0341 - accuracy: 0.9965
# Epoch 949/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0279 - accuracy: 0.9968
# Epoch 950/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0297 - accuracy: 0.9971
# Epoch 951/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0346 - accuracy: 0.9964
# Epoch 952/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0327 - accuracy: 0.9964
# Epoch 953/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0244 - accuracy: 0.9974
# Epoch 954/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0268 - accuracy: 0.9972
# Epoch 955/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0301 - accuracy: 0.9969
# Epoch 956/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0239 - accuracy: 0.9971
# Epoch 957/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0252 - accuracy: 0.9974
# Epoch 958/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0250 - accuracy: 0.9974
# Epoch 959/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0280 - accuracy: 0.9972
# Epoch 960/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0313 - accuracy: 0.9972
# Epoch 961/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0333 - accuracy: 0.9968
# Epoch 962/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0310 - accuracy: 0.9972
# Epoch 963/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0312 - accuracy: 0.9966
# Epoch 964/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0361 - accuracy: 0.9962
# Epoch 965/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0349 - accuracy: 0.9965
# Epoch 966/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0281 - accuracy: 0.9975
# Epoch 967/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0265 - accuracy: 0.9969
# Epoch 968/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0215 - accuracy: 0.9975
# Epoch 969/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0250 - accuracy: 0.9976
# Epoch 970/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0248 - accuracy: 0.9975
# Epoch 971/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0319 - accuracy: 0.9970
# Epoch 972/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0330 - accuracy: 0.9967
# Epoch 973/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0259 - accuracy: 0.9971
# Epoch 974/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0360 - accuracy: 0.9967
# Epoch 975/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0364 - accuracy: 0.9969
# Epoch 976/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0278 - accuracy: 0.9970
# Epoch 977/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0337 - accuracy: 0.9966
# Epoch 978/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0277 - accuracy: 0.9976
# Epoch 979/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0265 - accuracy: 0.9973
# Epoch 980/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0316 - accuracy: 0.9969
# Epoch 981/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0270 - accuracy: 0.9968
# Epoch 982/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0388 - accuracy: 0.9964
# Epoch 983/1000
# 391/391 [==============================] - 5s 13ms/step - loss: 0.0305 - accuracy: 0.9972
# Epoch 984/1000
# 391/391 [==============================] - 4s 12ms/step - loss: 0.0299 - accuracy: 0.9972
# Epoch 985/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0347 - accuracy: 0.9968
# Epoch 986/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0259 - accuracy: 0.9971
# Epoch 987/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0282 - accuracy: 0.9971
# Epoch 988/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0294 - accuracy: 0.9974
# Epoch 989/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0358 - accuracy: 0.9967
# Epoch 990/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0285 - accuracy: 0.9972
# Epoch 991/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0256 - accuracy: 0.9972
# Epoch 992/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0321 - accuracy: 0.9969
# Epoch 993/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0330 - accuracy: 0.9971
# Epoch 994/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0270 - accuracy: 0.9975
# Epoch 995/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0277 - accuracy: 0.9972
# Epoch 996/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0374 - accuracy: 0.9962
# Epoch 997/1000
# 391/391 [==============================] - 5s 14ms/step - loss: 0.0270 - accuracy: 0.9972
# Epoch 998/1000
# 391/391 [==============================] - 4s 11ms/step - loss: 0.0237 - accuracy: 0.9973
# Epoch 999/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0299 - accuracy: 0.9970
# Epoch 1000/1000
# 391/391 [==============================] - 5s 12ms/step - loss: 0.0291 - accuracy: 0.9975

# %% [markdown]
# The batch size determines how much data per step is used to compute the loss function, gradients, and backpropagation. Note that the accuracy increases after every epoch. We need to have a balanced number of epochs as higher epochs come at the risk of overfitting the model to the training set and may result in lower accuracy in the test case.

# %% [markdown]
# ## Evaluate the model
#
# We will now evaluate our model against the Testing dataset

# %%
score = model.evaluate(X_test, Y_test)
print(model.predict(X_test))
print('Test accuracy:', score[1])

# %% [markdown]
# Plot the accuracy and loss metrics of the model.

# %%
fig = plt.figure()
plt.subplot(2,1,1)
plt.plot(history.history['accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='lower right')

plt.subplot(2,1,2)
plt.plot(history.history['loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')

plt.tight_layout()

# %%
results = model.predict(X_test)

# %%
results = np.argmax(results,axis = 1)
results = pd.Series(results,name="Class")
submission = pd.concat([pd.Series(np.arange(0,len(X_test) ).astype(int),name = "Index"),results],axis = 1)

submission.to_csv("submission.csv",index=False)

# %%
submission
# Out:
#       Index  Class
# 0         0     14
# 1         1      7
# 2         2     10
# 3         3      7
# 4         4      5
# ...     ...    ...
# 9995   9995      7
# 9996   9996     12
# 9997   9997     10
# 9998   9998      4
# 9999   9999      6
#
# [10000 rows x 2 columns]

# %% [markdown]
# Now let us introspect a few correctly and wrongly classified images to get a better understanding of where the model fails and hopefully take corrective measures to increse its accuracy.

# %%
predicted_classes = model.predict_classes(X_test)

correct_indices = np.nonzero(predicted_classes == y_test)[0]

incorrect_indices = np.nonzero(predicted_classes != y_test)[0]

# %%
plt.figure()
for i, correct in enumerate(correct_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[correct].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[correct], y_test[correct]))
    
plt.tight_layout()
    
plt.figure()
for i, incorrect in enumerate(incorrect_indices[:9]):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[incorrect].reshape(28,28), cmap='gray', interpolation='none')
    plt.title("Predicted {}, Class {}".format(predicted_classes[incorrect], y_test[incorrect]))
    
plt.tight_layout()

# %% [markdown]
# Congratulations on completing your first Deep Learning model. I hope you understood the basic concepts behind data pre-processing, model framing, training, and testing.
#
# There are many ways in which we can improve the performance of the model by tuning the hyperparameters, data validation, augmentation, trying different optimizers and avoiding biased training, and many more!
#
# I have written a blog to give a better explanation of the approach I have used, here is the link - https://medium.com/analytics-vidhya/get-started-with-your-first-deep-learning-project-7d989cb13ae5
#
# Let me know if you have any suggestions/doubts. Happy Kaggling :)
